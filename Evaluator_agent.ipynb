# %%
import os
import re
import faiss
import numpy as np
import textdistance
import nltk
from nltk.util import ngrams
from nltk.tokenize import word_tokenize, sent_tokenize
from pdfminer.high_level import extract_text
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from rank_bm25 import BM25Okapi
from sentence_transformers import SentenceTransformer, util
from rouge_score import rouge_scorer
from collections import defaultdict
import textdistance
import re
nltk.download("punkt")
nltk.download('punkt_tab')
# Out:
# 2025-03-19 16:32:07.856874: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-19 16:32:07.916315: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742416327.954137 4191187 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742416327.964930 4191187 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-19 16:32:08.037544: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [nltk_data] Downloading package punkt to /home/mfasching/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/mfasching/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
class LLMOutputEvaluator:
    def __init__(self, pdf_path, llm_outputs,passage_length=1):
        """
        Initializes the evaluator.
        :param pdf_path: Path to the dedicated paper (PDF file)
        :param llm_outputs: Dictionary containing LLM-generated responses categorized by prompt type.
                            Example: {"Direct Prompting": "Generated text...", "Iterative Prompting": "..."}
        """
        self.pdf_path = pdf_path
        self.llm_outputs =  {key: self.clean_text(text) for key, text in llm_outputs.items()}
        self.sentence_model = SentenceTransformer("all-MiniLM-L6-v2")
        self.sentence_model_bert = SentenceTransformer('bert-base-nli-mean-tokens')
        self.tfidf_vectorizer = TfidfVectorizer()
        
        # **Extract and preprocess PDF**
        self.pdf_text = self.clean_text(self.extract_text_from_pdf())
        self.pdf_sentences = sent_tokenize(self.pdf_text)

        # **Create Passages from Sentences**
        # self.pdf_passages = self.create_passages(self.pdf_sentences, passage_length)

        # **Index PDF Passages in FAISS**
        self.faiss_index, self.sentence_embeddings = self.index_pdf_sentences()

        # ** Tokenized corpus for BM25
        self.bm25_corpus = [word_tokenize(sent) for sent in self.pdf_sentences]
        self.bm25_model = BM25Okapi(self.bm25_corpus)

    def extract_text_from_pdf(self):
        """Extract text from PDF file."""
        return extract_text(self.pdf_path)

    def clean_text(self, text):
        # Remove unwanted characters
        text = re.sub(r'\s+', ' ', text)  # Replace multiple whitespace with a single space
        text = re.sub(r'[^\x20-\x7E]+', ' ', text)  # Remove non-printable characters
        text = re.sub(r'(\d+)\.', r'\1 ', text) # removes . after number
        return text.strip().lower()  # Remove leading and trailing whitespace

    # def create_passages(self, sentences, passage_length):
    #     """
    #     Groups sentences into passages.
    #     Example: passage_length=3 means each passage consists of 3 sentences.
    #     """
    #     passages = [" ".join(sentences[i:i + passage_length]) for i in range(0, len(sentences), passage_length)]
    #     return passages
    
    def index_pdf_sentences(self):
        """
        Embeds and indexes the PDF passages using FAISS for fast retrieval.
        """
        sentence_embeddings = np.array(self.sentence_model.encode(self.pdf_sentences, convert_to_numpy=True))

        # **FAISS Index**
        dimension = sentence_embeddings.shape[1]
        faiss_index = faiss.IndexFlatL2(dimension)
        faiss_index.add(sentence_embeddings)

        return faiss_index, sentence_embeddings

    # ---------------- SIMILAR PDF PASSAGES BETWEEN PDF AND LLM OUTPUT --------------------------
    
    def faiss_vector_search(self, llm_text, top_k=5):
        """
        Finds the top-k most similar PDF passages to the given LLM text.
        :param llm_text: LLM-generated text.
        :param top_k: Number of closest passages to return.
        """
        # **Encode the LLM output**
        query_embedding = np.array(self.sentence_model.encode([llm_text], convert_to_numpy=True))

        # **FAISS search**
        distances, indices = self.faiss_index.search(query_embedding, top_k)

        # **Retrieve closest passages**
        closest_passages = [(self.pdf_sentences[idx], 1 - distances[0][i]) for i, idx in enumerate(indices[0])]
        return closest_passages  # List of (passage, similarity_score)

    def bert_sentence_similarity(self, llm_text, top_k=5):
        """Computes sentence similarity using BERT embeddings."""
        # Tokenize texts into sentences
        llm_sentences = sent_tokenize(llm_text)
        # Prepare output with sentences and their similarities
        output = []

        for sent1 in llm_sentences:
            for sent2 in self.pdf_sentences:
                # Compute embeddings for both sentences
                embeddings = self.sentence_model_bert.encode([sent1, sent2], convert_to_tensor=True)
                # Calculate cosine similarity
                similarity = util.pytorch_cos_sim(embeddings[0], embeddings[1]).item()
                # Append the sentences and their similarity score
                output.append((sent1, sent2, similarity))
        
        # Sort output based on similarity score in descending order
        sorted_output = sorted(output, key=lambda x: x[2], reverse=True)
        
        return sorted_output[:top_k]


    #----------------------------- SIMILARITY METRICS ------------------------
    
    
    def levenshtein_distance(self, text1, text2):
        """Computes Levenshtein Distance (Edit Distance)."""
        if not isinstance(text1, str) or not isinstance(text2, str):
            raise ValueError(f"Expected strings, got {type(text1)} and {type(text2)}")
        return textdistance.levenshtein.normalized_similarity(text1, text2)

    def jaccard_similarity(self, sentence1, sentence2):
        """Computes Jaccard Similarity between two texts."""
        words1 = set(word_tokenize(sentence1))
        words2 = set(word_tokenize(sentence2))
        
        # Calculate Jaccard similarity
        intersection = len(words1.intersection(words2))
        union = len(words1.union(words2))
        
        if union == 0:
            return 0.0
        
        return intersection / union


    def tfidf_cosine_similarity(self, sentence1, sentence2):
        """Computes TF-IDF based Cosine Similarity."""
        # Combine the two sentences into a list
        combined_sentences = [sentence1, sentence2]
        
        tfidf_matrix = self.tfidf_vectorizer.fit_transform(combined_sentences)
        similarity_matrix = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])        
        return similarity_matrix[0][0]

    def bleu_score(self, llm_sentence, pdf_sentence):
        """Computes BLEU score using n-grams."""
        llm_tokens = word_tokenize(llm_sentence.lower())
        pdf_tokens = word_tokenize(pdf_sentence.lower())
        # Calculate BLEU score
        bleu_score = nltk.translate.bleu_score.sentence_bleu([pdf_tokens], llm_tokens)
        return bleu_score

    def rouge_score(self, sentence1, sentence2):
        """Computes ROUGE score."""
        # Initialize the ROUGE scorer
        scorer = rouge_scorer.RougeScorer(["rouge1", "rouge2", "rougeL"], use_stemmer=True)
        
        # Calculate ROUGE scores
        scores = scorer.score(sentence1, sentence2)
        
        return scores

    def longest_common_substring(self, sentence1, sentence2):
        """Computes the longest common substring length."""
        match = textdistance.lcsseq(sentence1, sentence2)
        return len(match) / max(len(sentence1), len(sentence2))

    def longest_common_subsequence_and_acs(self, sentence1, sentence2):
        """Computes the longest common subsequence length and accumulated common subsequences length."""
        m, n = len(sentence1), len(sentence2)
        dp = [[0] * (n + 1) for _ in range(m + 1)]

        total_common_subseq_length = 0
    
        for i in range(1, m + 1):
            for j in range(1, n + 1):
                if sentence1[i - 1] == sentence2[j - 1]:
                    dp[i][j] = dp[i - 1][j - 1] + 1
                else:
                    dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])
        
        lcs_length = dp[m][n]
        max_length = max(m, n)
        lcs_percentage = (lcs_length / max_length) * 100 if max_length > 0 else 0
    
        for i in range(m + 1):
            for j in range(n + 1):
                total_common_subseq_length += dp[i][j]
    
        return lcs_percentage, total_common_subseq_length

    # ----------------------------- MAIN EVALUATION  ------------------------
    
    def evaluate_llm_outputs(self):
        """Evaluates LLM outputs against the original paper using various metrics."""
        results = defaultdict(dict)

        for prompt_type, llm_text in self.llm_outputs.items():
            print("Finding similar passages in pdf")
            llm_sentences = sent_tokenize(llm_text)
            bert_sentences = self.bert_sentence_similarity(llm_text, top_k=5)
            
            similar_pdf_sentences = self.faiss_vector_search(llm_text, top_k=5) + bert_sentences
            # closest_pdf_passages = " ".join([p[0] for p in self.faiss_vector_search(llm_text, top_k=5)])
            # closest_pdf_passages += ' '.join([p[0] for p in self.bert_sentence_similarity(llm_text, top_k=5)]) 
            result = {}
            # Tokenize LLM and PDF sentences
            # print(similar_pdf_sentences)
            # print(llm_sentences)
            
            print(f"\nEvaluating: {prompt_type}")
            for llm_sentence in llm_sentences:
                for pdf_sentence in similar_pdf_sentences:
                    lcs_percentage, acs_length = self.longest_common_subsequence_and_acs(llm_sentence, pdf_sentence[0])
                    result[(llm_sentence, pdf_sentence)] = {
                        'bert_sentence_similarity': 
                        'levenshtein_distance': self.levenshtein_distance(llm_sentence, pdf_sentence[0]),
                        'jaccard_similarity': self.jaccard_similarity(llm_sentence, pdf_sentence[0]),
                        'tfidf_cosine_similarity': self.tfidf_cosine_similarity(llm_sentence, pdf_sentence[0]),
                        'bleu_score': self.bleu_score(llm_sentence, pdf_sentence[0]),
                        'rouge_score': self.rouge_score(llm_sentence, pdf_sentence[0]),
                        'longest_common_substring': self.longest_common_substring(llm_sentence, pdf_sentence[0]),
                        'lcs_percentage': lcs_percentage,
                        'acs_length': acs_length
                    }
        
            results[prompt_type] = result
        
        return results

    def output_pdf_text(self):
        return self.sentences

# %%
pdf_path = '/home/mfasching/gpt4free/papers/PromptCARE.pdf'

llm_outputs = {
        "Direct Prompting": 'To provide a detailed comparison, we first need to identify a work that is similar to "PromptCARE: Prompt Copyright Protection by Watermark Injection and Verification." While I don\'t have access to specific databases or the latest research papers, I can suggest a general approach based on common themes in copyright protection and watermarking techniques.\n\n### Similar Work\nOne of the most similar works in the field of copyright protection and watermarking is "Digital Watermarking for Copyright Protection" by Cox et al. This work discusses various techniques for embedding watermarks into digital content to protect copyright and verify ownership.\n\n### Main Differences\nHere are some potential differences between "PromptCARE" and the work by Cox et al.:\n\n1. **Methodology**:\n   - **PromptCARE**: This work may focus on a specific method of watermark injection that is tailored for prompts or text-based content, possibly using natural language processing (NLP) techniques to ensure that the watermark does not alter the meaning or usability of the text.\n   - **Cox et al.**: This work might employ more traditional methods of watermarking, which could include spatial or frequency domain techniques primarily used for images or audio, rather than text.\n\n2. **Type of Content**:\n   - **PromptCARE**: Specifically designed for text prompts, which are often used in AI and machine learning contexts. The watermarking technique may need to consider the syntactic and semantic integrity of the text.\n   - **Cox et al.**: Generally applicable to multimedia content like images, audio, and video. The techniques discussed may not be directly applicable to text without significant adaptation.\n\n3. **Verification Process**:\n   - **PromptCARE**: The verification process might involve NLP techniques to analyze the text and confirm the presence of the watermark, possibly using machine learning models to detect alterations or verify authenticity.\n   - **Cox et al.**: The verification methods may rely on more straightforward extraction techniques that are effective for visual or auditory content but may not translate well to text.\n\n4. **Robustness and Security**:\n   - **PromptCARE**: The robustness of the watermark against various forms of text manipulation (e.g., paraphrasing, synonym replacement) could be a key focus, ensuring that the watermark remains intact even after such alterations.\n   - **Cox et al.**: While robustness is also a concern, the focus may be more on resilience against common attacks like compression or cropping, which are more relevant to images and audio.\n\n5. **Applications**:\n   - **PromptCARE**: Likely aimed at protecting AI-generated content, ensuring that prompts used in models are attributed correctly and not misused.\n   - **Cox et al.**: More broadly applicable to any digital content, focusing on general copyright issues across various media types.\n\n### Detailed Examples\n- **Example of Methodology**: If PromptCARE uses a technique where specific keywords or phrases are subtly altered to include a watermark, Cox et al. might use a method where pixel values in an image are adjusted to embed a watermark, which is a fundamentally different approach.\n  \n- **Example of Verification**: In PromptCARE, the verification might involve checking the semantic meaning of the text to ensure the watermark is still present after modifications, while in Cox et al., the verification might involve checking for specific frequency patterns in an audio file.\n\n- **Example of Robustness**: If PromptCARE\'s watermark can withstand paraphrasing (e.g., changing "This is a test" to "This is merely an experiment"), Cox et al.\'s watermark might be tested against image compression techniques, which would not apply to text.\n\nIn summary, while both works focus on copyright protection through watermarking, they differ significantly in their methodologies, types of content addressed, verification processes, robustness against specific attacks, and applications.',
        "Iterative Refinement": "Recent advancements in large language models (LLMs) have enabled...",
        "Meta-Instruction Prompting": "The significance of prompt engineering in LLMs has grown substantially...",
        "Contrastive Extraction": "Unlike traditional AI models, LLMs adapt by using...",
        "Levenshtein Distance": "Unlike traditional AI models, LLMs adapt by using"
    }

evaluator = LLMOutputEvaluator(pdf_path, llm_outputs)

text = evaluator.evaluate_llm_outputs()
# Out:
# Finding similar passages in pdf
#
# Evaluating: Direct Prompting
# Finding similar passages in pdf
#
# Evaluating: Iterative Refinement
# Finding similar passages in pdf
#
# Evaluating: Meta-Instruction Prompting
# Finding similar passages in pdf
#
# Evaluating: Contrastive Extraction
# Finding similar passages in pdf
#
# Evaluating: Levenshtein Distance

# %%
text
# Out:
# defaultdict(dict,
#             {'Direct Prompting': {('to provide a detailed comparison, we first need to identify a work that is similar to "promptcare: prompt copyright protection by watermark injection and verification."',
#                ('b.1  summary the paper introduces a framework, promptcare, aimed at protecting prompt copyright through watermark injection and verification.',
#                 0.5114053189754486)): {'levenshtein_distance': 0.48809523809523814,
#                'jaccard_similarity': 0.2702702702702703,
#                'bleu_score': 0.14614031921776124,
#                'tfidf_cosine_similarity': 0.1979716352656667,
#                'rouge_score': {'rouge1': Score(precision=0.47368421052631576, recall=0.36, fmeasure=0.40909090909090906),
#                 'rouge2': Score(precision=0.2222222222222222, recall=0.16666666666666666, fmeasure=0.1904761904761905),
#                 'rougeL': Score(precision=0.42105263157894735, recall=0.32, fmeasure=0.3636363636363636)},
#                'longest_common_substring': 0.5714285714285714,
#                'longest_common_subsequence': 96},
#               ('to provide a detailed comparison, we first need to identify a work that is similar to "promptcare: prompt copyright protection by watermark injection and verification."',
#                ('in this paper, we propose promptcare, the first framework for prompt copyright protection through watermark injection and verification.',
#                 0.4955151081085205)): {'levenshtein_distance': 0.5238095238095238,
#                'jaccard_similarity': 0.34285714285714286,
#                'bleu_score': 0.17878540236558915,
#                'tfidf_cosine_similarity': 0.285547186049373,
#                'rouge_score': {'rouge1': Score(precision=0.5555555555555556, recall=0.4, fmeasure=0.46511627906976744),
#                 'rouge2': Score(precision=0.29411764705882354, recall=0.20833333333333334, fmeasure=0.24390243902439027),
#                 'rougeL': Score(precision=0.5, recall=0.36, fmeasure=0.41860465116279066)},
#                'longest_common_substring': 0.5952380952380952,
#                'longest_common_subsequence': 100},
#               ('to provide a detailed comparison, we first need to identify a work that is similar to "promptcare: prompt copyright protection by watermark injection and verification."',
#                ('among all these methods, watermarking is a promising candidate technique for prompt copyright protection due to its effectiveness.',
#                 0.4763607978820801)): {'levenshtein_distance': 0.3571428571428571,
#                'jaccard_similarity': 0.20512820512820512,
#                'bleu_score': 1.9552251842690608e-78,
#                'tfidf_cosine_similarity': 0.1956291783810017,
#                'rouge_score': {'rouge1': Score(precision=0.3888888888888889, recall=0.28, fmeasure=0.32558139534883723),
#                 'rouge2': Score(precision=0.11764705882352941, recall=0.08333333333333333, fmeasure=0.09756097560975609),
#                 'rougeL': Score(precision=0.2222222222222222, recall=0.16, fmeasure=0.18604651162790697)},
#                'longest_common_substring': 0.43452380952380953,
#                'longest_common_subsequence': 73},
#               ('to provide a detailed comparison, we first need to identify a work that is similar to "promptcare: prompt copyright protection by watermark injection and verification."',
#                ('to overcome the above hurdles, we propose promptcare: prompt copyright protection by watermark injection and verification.',
#                 0.4687466621398926)): {'levenshtein_distance': 0.6011904761904762,
#                'jaccard_similarity': 0.4375,
#                'bleu_score': 0.36033217429111203,
#                'tfidf_cosine_similarity': 0.4570443741990192,
#                'rouge_score': {'rouge1': Score(precision=0.6875, recall=0.44, fmeasure=0.5365853658536586),
#                 'rouge2': Score(precision=0.5333333333333333, recall=0.3333333333333333, fmeasure=0.4102564102564102),
#                 'rougeL': Score(precision=0.6875, recall=0.44, fmeasure=0.5365853658536586)},
#                'longest_common_substring': 0.6190476190476191,
#                'longest_common_subsequence': 104},
#               ('to provide a detailed comparison, we first need to identify a work that is similar to "promptcare: prompt copyright protection by watermark injection and verification."',
#                ('prompt watermarking presents unique chal- lenges that render existing watermarking techniques devel- oped for model and dataset copyright verification ineffective.',
#                 0.45281028747558594)): {'levenshtein_distance': 0.2142857142857143,
#                'jaccard_similarity': 0.14634146341463414,
#                'bleu_score': 1.2183324802375697e-231,
#                'tfidf_cosine_similarity': 0.11119533668012423,
#                'rouge_score': {'rouge1': Score(precision=0.3, recall=0.24, fmeasure=0.2666666666666666),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.2, recall=0.16, fmeasure=0.17777777777777778)},
#                'longest_common_substring': 0.44047619047619047,
#                'longest_common_subsequence': 74},
#               ('to provide a detailed comparison, we first need to identify a work that is similar to "promptcare: prompt copyright protection by watermark injection and verification."',
#                ('to overcome the above hurdles, we propose promptcare: prompt copyright protection by watermark injection and verification.',
#                 0.9345049262046814)): {'levenshtein_distance': 0.6011904761904762,
#                'jaccard_similarity': 0.4375,
#                'bleu_score': 0.36033217429111203,
#                'tfidf_cosine_similarity': 0.4570443741990192,
#                'rouge_score': {'rouge1': Score(precision=0.6875, recall=0.44, fmeasure=0.5365853658536586),
#                 'rouge2': Score(precision=0.5333333333333333, recall=0.3333333333333333, fmeasure=0.4102564102564102),
#                 'rougeL': Score(precision=0.6875, recall=0.44, fmeasure=0.5365853658536586)},
#                'longest_common_substring': 0.6190476190476191,
#                'longest_common_subsequence': 104},
#               ('to provide a detailed comparison, we first need to identify a work that is similar to "promptcare: prompt copyright protection by watermark injection and verification."',
#                ('b.1  summary the paper introduces a framework, promptcare, aimed at protecting prompt copyright through watermark injection and verification.',
#                 0.9129835963249207)): {'levenshtein_distance': 0.48809523809523814,
#                'jaccard_similarity': 0.2702702702702703,
#                'bleu_score': 0.14614031921776124,
#                'tfidf_cosine_similarity': 0.1979716352656667,
#                'rouge_score': {'rouge1': Score(precision=0.47368421052631576, recall=0.36, fmeasure=0.40909090909090906),
#                 'rouge2': Score(precision=0.2222222222222222, recall=0.16666666666666666, fmeasure=0.1904761904761905),
#                 'rougeL': Score(precision=0.42105263157894735, recall=0.32, fmeasure=0.3636363636363636)},
#                'longest_common_substring': 0.5714285714285714,
#                'longest_common_subsequence': 96},
#               ('to provide a detailed comparison, we first need to identify a work that is similar to "promptcare: prompt copyright protection by watermark injection and verification."',
#                ('in this paper, we propose promptcare, the first framework for prompt copyright protection through watermark injection and verification.',
#                 0.9047225117683411)): {'levenshtein_distance': 0.5238095238095238,
#                'jaccard_similarity': 0.34285714285714286,
#                'bleu_score': 0.17878540236558915,
#                'tfidf_cosine_similarity': 0.285547186049373,
#                'rouge_score': {'rouge1': Score(precision=0.5555555555555556, recall=0.4, fmeasure=0.46511627906976744),
#                 'rouge2': Score(precision=0.29411764705882354, recall=0.20833333333333334, fmeasure=0.24390243902439027),
#                 'rougeL': Score(precision=0.5, recall=0.36, fmeasure=0.41860465116279066)},
#                'longest_common_substring': 0.5952380952380952,
#                'longest_common_subsequence': 100},
#               ('to provide a detailed comparison, we first need to identify a work that is similar to "promptcare: prompt copyright protection by watermark injection and verification."',
#                ('we propose promptcare, a prompt watermark injection and verification framework that is used to verify the copyright of the prompt used on a suspected llm service provider.',
#                 0.8855746984481812)): {'levenshtein_distance': 0.30409356725146197,
#                'jaccard_similarity': 0.3684210526315789,
#                'bleu_score': 0.11622111816655838,
#                'tfidf_cosine_similarity': 0.326030625936705,
#                'rouge_score': {'rouge1': Score(precision=0.5185185185185185, recall=0.56, fmeasure=0.5384615384615384),
#                 'rouge2': Score(precision=0.15384615384615385, recall=0.16666666666666666, fmeasure=0.16),
#                 'rougeL': Score(precision=0.25925925925925924, recall=0.28, fmeasure=0.2692307692307692)},
#                'longest_common_substring': 0.47953216374269003,
#                'longest_common_subsequence': 82},
#               ('to provide a detailed comparison, we first need to identify a work that is similar to "promptcare: prompt copyright protection by watermark injection and verification."',
#                ('during   the verification of the watermark, the defender has the ability to embed specific triggers (i.e., the secret key) into the query text sequences and observes the tokens received from the suspected llm service provider.',
#                 0.8460875153541565)): {'levenshtein_distance': 0.23451327433628322,
#                'jaccard_similarity': 0.11320754716981132,
#                'bleu_score': 8.729733687792411e-232,
#                'tfidf_cosine_similarity': 0.06739659914171282,
#                'rouge_score': {'rouge1': Score(precision=0.1388888888888889, recall=0.2, fmeasure=0.1639344262295082),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.05555555555555555, recall=0.08, fmeasure=0.06557377049180328)},
#                'longest_common_substring': 0.3230088495575221,
#                'longest_common_subsequence': 73},
#               ("while i don't have access to specific databases or the latest research papers, i can suggest a general approach based on common themes in copyright protection and watermarking techniques.",
#                ('b.1  summary the paper introduces a framework, promptcare, aimed at protecting prompt copyright through watermark injection and verification.',
#                 0.5114053189754486)): {'levenshtein_distance': 0.28342245989304815,
#                'jaccard_similarity': 0.13333333333333333,
#                'bleu_score': 1.1988328686372911e-231,
#                'tfidf_cosine_similarity': 0.08049479014736127,
#                'rouge_score': {'rouge1': Score(precision=0.3684210526315789, recall=0.23333333333333334, fmeasure=0.2857142857142857),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.2631578947368421, recall=0.16666666666666666, fmeasure=0.2040816326530612)},
#                'longest_common_substring': 0.39037433155080214,
#                'longest_common_subsequence': 73},
#               ("while i don't have access to specific databases or the latest research papers, i can suggest a general approach based on common themes in copyright protection and watermarking techniques.",
#                ('in this paper, we propose promptcare, the first framework for prompt copyright protection through watermark injection and verification.',
#                 0.4955151081085205)): {'levenshtein_distance': 0.3048128342245989,
#                'jaccard_similarity': 0.1590909090909091,
#                'bleu_score': 4.3233341924983234e-155,
#                'tfidf_cosine_similarity': 0.1324051456142385,
#                'rouge_score': {'rouge1': Score(precision=0.3888888888888889, recall=0.23333333333333334, fmeasure=0.2916666666666667),
#                 'rouge2': Score(precision=0.058823529411764705, recall=0.034482758620689655, fmeasure=0.043478260869565216),
#                 'rougeL': Score(precision=0.2222222222222222, recall=0.13333333333333333, fmeasure=0.16666666666666669)},
#                'longest_common_substring': 0.40106951871657753,
#                'longest_common_subsequence': 75},
#               ("while i don't have access to specific databases or the latest research papers, i can suggest a general approach based on common themes in copyright protection and watermarking techniques.",
#                ('among all these methods, watermarking is a promising candidate technique for prompt copyright protection due to its effectiveness.',
#                 0.4763607978820801)): {'levenshtein_distance': 0.3315508021390374,
#                'jaccard_similarity': 0.1590909090909091,
#                'bleu_score': 4.3233341924983234e-155,
#                'tfidf_cosine_similarity': 0.10658141524382438,
#                'rouge_score': {'rouge1': Score(precision=0.3333333333333333, recall=0.2, fmeasure=0.25),
#                 'rouge2': Score(precision=0.058823529411764705, recall=0.034482758620689655, fmeasure=0.043478260869565216),
#                 'rougeL': Score(precision=0.16666666666666666, recall=0.1, fmeasure=0.125)},
#                'longest_common_substring': 0.39572192513368987,
#                'longest_common_subsequence': 74},
#               ("while i don't have access to specific databases or the latest research papers, i can suggest a general approach based on common themes in copyright protection and watermarking techniques.",
#                ('to overcome the above hurdles, we propose promptcare: prompt copyright protection by watermark injection and verification.',
#                 0.4687466621398926)): {'levenshtein_distance': 0.31016042780748665,
#                'jaccard_similarity': 0.16279069767441862,
#                'bleu_score': 4.3233341924983234e-155,
#                'tfidf_cosine_similarity': 0.14185321125913083,
#                'rouge_score': {'rouge1': Score(precision=0.375, recall=0.2, fmeasure=0.26086956521739135),
#                 'rouge2': Score(precision=0.06666666666666667, recall=0.034482758620689655, fmeasure=0.045454545454545456),
#                 'rougeL': Score(precision=0.3125, recall=0.16666666666666666, fmeasure=0.21739130434782608)},
#                'longest_common_substring': 0.40106951871657753,
#                'longest_common_subsequence': 75},
#               ("while i don't have access to specific databases or the latest research papers, i can suggest a general approach based on common themes in copyright protection and watermarking techniques.",
#                ('prompt watermarking presents unique chal- lenges that render existing watermarking techniques devel- oped for model and dataset copyright verification ineffective.',
#                 0.45281028747558594)): {'levenshtein_distance': 0.27807486631016043,
#                'jaccard_similarity': 0.10869565217391304,
#                'bleu_score': 3.974539328672128e-155,
#                'tfidf_cosine_similarity': 0.11992234159711519,
#                'rouge_score': {'rouge1': Score(precision=0.2, recall=0.13333333333333333, fmeasure=0.16),
#                 'rouge2': Score(precision=0.05263157894736842, recall=0.034482758620689655, fmeasure=0.041666666666666664),
#                 'rougeL': Score(precision=0.1, recall=0.06666666666666667, fmeasure=0.08)},
#                'longest_common_substring': 0.41711229946524064,
#                'longest_common_subsequence': 78},
#               ("while i don't have access to specific databases or the latest research papers, i can suggest a general approach based on common themes in copyright protection and watermarking techniques.",
#                ('to overcome the above hurdles, we propose promptcare: prompt copyright protection by watermark injection and verification.',
#                 0.9345049262046814)): {'levenshtein_distance': 0.31016042780748665,
#                'jaccard_similarity': 0.16279069767441862,
#                'bleu_score': 4.3233341924983234e-155,
#                'tfidf_cosine_similarity': 0.14185321125913083,
#                'rouge_score': {'rouge1': Score(precision=0.375, recall=0.2, fmeasure=0.26086956521739135),
#                 'rouge2': Score(precision=0.06666666666666667, recall=0.034482758620689655, fmeasure=0.045454545454545456),
#                 'rougeL': Score(precision=0.3125, recall=0.16666666666666666, fmeasure=0.21739130434782608)},
#                'longest_common_substring': 0.40106951871657753,
#                'longest_common_subsequence': 75},
#               ("while i don't have access to specific databases or the latest research papers, i can suggest a general approach based on common themes in copyright protection and watermarking techniques.",
#                ('b.1  summary the paper introduces a framework, promptcare, aimed at protecting prompt copyright through watermark injection and verification.',
#                 0.9129835963249207)): {'levenshtein_distance': 0.28342245989304815,
#                'jaccard_similarity': 0.13333333333333333,
#                'bleu_score': 1.1988328686372911e-231,
#                'tfidf_cosine_similarity': 0.08049479014736127,
#                'rouge_score': {'rouge1': Score(precision=0.3684210526315789, recall=0.23333333333333334, fmeasure=0.2857142857142857),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.2631578947368421, recall=0.16666666666666666, fmeasure=0.2040816326530612)},
#                'longest_common_substring': 0.39037433155080214,
#                'longest_common_subsequence': 73},
#               ("while i don't have access to specific databases or the latest research papers, i can suggest a general approach based on common themes in copyright protection and watermarking techniques.",
#                ('in this paper, we propose promptcare, the first framework for prompt copyright protection through watermark injection and verification.',
#                 0.9047225117683411)): {'levenshtein_distance': 0.3048128342245989,
#                'jaccard_similarity': 0.1590909090909091,
#                'bleu_score': 4.3233341924983234e-155,
#                'tfidf_cosine_similarity': 0.1324051456142385,
#                'rouge_score': {'rouge1': Score(precision=0.3888888888888889, recall=0.23333333333333334, fmeasure=0.2916666666666667),
#                 'rouge2': Score(precision=0.058823529411764705, recall=0.034482758620689655, fmeasure=0.043478260869565216),
#                 'rougeL': Score(precision=0.2222222222222222, recall=0.13333333333333333, fmeasure=0.16666666666666669)},
#                'longest_common_substring': 0.40106951871657753,
#                'longest_common_subsequence': 75},
#               ("while i don't have access to specific databases or the latest research papers, i can suggest a general approach based on common themes in copyright protection and watermarking techniques.",
#                ('we propose promptcare, a prompt watermark injection and verification framework that is used to verify the copyright of the prompt used on a suspected llm service provider.',
#                 0.8855746984481812)): {'levenshtein_distance': 0.25133689839572193,
#                'jaccard_similarity': 0.16666666666666666,
#                'bleu_score': 1.2882297539194154e-231,
#                'tfidf_cosine_similarity': 0.12039422224908271,
#                'rouge_score': {'rouge1': Score(precision=0.25925925925925924, recall=0.23333333333333334, fmeasure=0.2456140350877193),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.1111111111111111, recall=0.1, fmeasure=0.10526315789473685)},
#                'longest_common_substring': 0.4117647058823529,
#                'longest_common_subsequence': 77},
#               ("while i don't have access to specific databases or the latest research papers, i can suggest a general approach based on common themes in copyright protection and watermarking techniques.",
#                ('during   the verification of the watermark, the defender has the ability to embed specific triggers (i.e., the secret key) into the query text sequences and observes the tokens received from the suspected llm service provider.',
#                 0.8460875153541565)): {'levenshtein_distance': 0.26106194690265483,
#                'jaccard_similarity': 0.10526315789473684,
#                'bleu_score': 9.33651976866461e-232,
#                'tfidf_cosine_similarity': 0.15058958368375397,
#                'rouge_score': {'rouge1': Score(precision=0.16666666666666666, recall=0.2, fmeasure=0.1818181818181818),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.1111111111111111, recall=0.13333333333333333, fmeasure=0.1212121212121212)},
#                'longest_common_substring': 0.3672566371681416,
#                'longest_common_subsequence': 83},
#               ('### similar work one of the most similar works in the field of copyright protection and watermarking is "digital watermarking for copyright protection" by cox et al.',
#                ('b.1  summary the paper introduces a framework, promptcare, aimed at protecting prompt copyright through watermark injection and verification.',
#                 0.5114053189754486)): {'levenshtein_distance': 0.2909090909090909,
#                'jaccard_similarity': 0.1,
#                'bleu_score': 1.0832677820940877e-231,
#                'tfidf_cosine_similarity': 0.11467775046429292,
#                'rouge_score': {'rouge1': Score(precision=0.2631578947368421, recall=0.19230769230769232, fmeasure=0.2222222222222222),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.15789473684210525, recall=0.11538461538461539, fmeasure=0.13333333333333333)},
#                'longest_common_substring': 0.41818181818181815,
#                'longest_common_subsequence': 69},
#               ('### similar work one of the most similar works in the field of copyright protection and watermarking is "digital watermarking for copyright protection" by cox et al.',
#                ('in this paper, we propose promptcare, the first framework for prompt copyright protection through watermark injection and verification.',
#                 0.4955151081085205)): {'levenshtein_distance': 0.32121212121212117,
#                'jaccard_similarity': 0.1891891891891892,
#                'bleu_score': 4.3233341924983234e-155,
#                'tfidf_cosine_similarity': 0.21242193483843047,
#                'rouge_score': {'rouge1': Score(precision=0.3888888888888889, recall=0.2692307692307692, fmeasure=0.3181818181818182),
#                 'rouge2': Score(precision=0.058823529411764705, recall=0.04, fmeasure=0.04761904761904763),
#                 'rougeL': Score(precision=0.2777777777777778, recall=0.19230769230769232, fmeasure=0.2272727272727273)},
#                'longest_common_substring': 0.4666666666666667,
#                'longest_common_subsequence': 77},
#               ('### similar work one of the most similar works in the field of copyright protection and watermarking is "digital watermarking for copyright protection" by cox et al.',
#                ('among all these methods, watermarking is a promising candidate technique for prompt copyright protection due to its effectiveness.',
#                 0.4763607978820801)): {'levenshtein_distance': 0.2909090909090909,
#                'jaccard_similarity': 0.15789473684210525,
#                'bleu_score': 4.946973787525366e-155,
#                'tfidf_cosine_similarity': 0.19054892548218932,
#                'rouge_score': {'rouge1': Score(precision=0.2777777777777778, recall=0.19230769230769232, fmeasure=0.2272727272727273),
#                 'rouge2': Score(precision=0.11764705882352941, recall=0.08, fmeasure=0.09523809523809526),
#                 'rougeL': Score(precision=0.2777777777777778, recall=0.19230769230769232, fmeasure=0.2272727272727273)},
#                'longest_common_substring': 0.43636363636363634,
#                'longest_common_subsequence': 72},
#               ('### similar work one of the most similar works in the field of copyright protection and watermarking is "digital watermarking for copyright protection" by cox et al.',
#                ('to overcome the above hurdles, we propose promptcare: prompt copyright protection by watermark injection and verification.',
#                 0.4687466621398926)): {'levenshtein_distance': 0.33333333333333337,
#                'jaccard_similarity': 0.16216216216216217,
#                'bleu_score': 4.1598925242842284e-155,
#                'tfidf_cosine_similarity': 0.19746451626740025,
#                'rouge_score': {'rouge1': Score(precision=0.375, recall=0.23076923076923078, fmeasure=0.2857142857142857),
#                 'rouge2': Score(precision=0.13333333333333333, recall=0.08, fmeasure=0.1),
#                 'rougeL': Score(precision=0.25, recall=0.15384615384615385, fmeasure=0.1904761904761905)},
#                'longest_common_substring': 0.4303030303030303,
#                'longest_common_subsequence': 71},
#               ('### similar work one of the most similar works in the field of copyright protection and watermarking is "digital watermarking for copyright protection" by cox et al.',
#                ('prompt watermarking presents unique chal- lenges that render existing watermarking techniques devel- oped for model and dataset copyright verification ineffective.',
#                 0.45281028747558594)): {'levenshtein_distance': 0.24848484848484853,
#                'jaccard_similarity': 0.1282051282051282,
#                'bleu_score': 1.1988328686372911e-231,
#                'tfidf_cosine_similarity': 0.16356264089818384,
#                'rouge_score': {'rouge1': Score(precision=0.25, recall=0.19230769230769232, fmeasure=0.2173913043478261),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.2, recall=0.15384615384615385, fmeasure=0.17391304347826086)},
#                'longest_common_substring': 0.4484848484848485,
#                'longest_common_subsequence': 74},
#               ('### similar work one of the most similar works in the field of copyright protection and watermarking is "digital watermarking for copyright protection" by cox et al.',
#                ('to overcome the above hurdles, we propose promptcare: prompt copyright protection by watermark injection and verification.',
#                 0.9345049262046814)): {'levenshtein_distance': 0.33333333333333337,
#                'jaccard_similarity': 0.16216216216216217,
#                'bleu_score': 4.1598925242842284e-155,
#                'tfidf_cosine_similarity': 0.19746451626740025,
#                'rouge_score': {'rouge1': Score(precision=0.375, recall=0.23076923076923078, fmeasure=0.2857142857142857),
#                 'rouge2': Score(precision=0.13333333333333333, recall=0.08, fmeasure=0.1),
#                 'rougeL': Score(precision=0.25, recall=0.15384615384615385, fmeasure=0.1904761904761905)},
#                'longest_common_substring': 0.4303030303030303,
#                'longest_common_subsequence': 71},
#               ('### similar work one of the most similar works in the field of copyright protection and watermarking is "digital watermarking for copyright protection" by cox et al.',
#                ('b.1  summary the paper introduces a framework, promptcare, aimed at protecting prompt copyright through watermark injection and verification.',
#                 0.9129835963249207)): {'levenshtein_distance': 0.2909090909090909,
#                'jaccard_similarity': 0.1,
#                'bleu_score': 1.0832677820940877e-231,
#                'tfidf_cosine_similarity': 0.11467775046429292,
#                'rouge_score': {'rouge1': Score(precision=0.2631578947368421, recall=0.19230769230769232, fmeasure=0.2222222222222222),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.15789473684210525, recall=0.11538461538461539, fmeasure=0.13333333333333333)},
#                'longest_common_substring': 0.41818181818181815,
#                'longest_common_subsequence': 69},
#               ('### similar work one of the most similar works in the field of copyright protection and watermarking is "digital watermarking for copyright protection" by cox et al.',
#                ('in this paper, we propose promptcare, the first framework for prompt copyright protection through watermark injection and verification.',
#                 0.9047225117683411)): {'levenshtein_distance': 0.32121212121212117,
#                'jaccard_similarity': 0.1891891891891892,
#                'bleu_score': 4.3233341924983234e-155,
#                'tfidf_cosine_similarity': 0.21242193483843047,
#                'rouge_score': {'rouge1': Score(precision=0.3888888888888889, recall=0.2692307692307692, fmeasure=0.3181818181818182),
#                 'rouge2': Score(precision=0.058823529411764705, recall=0.04, fmeasure=0.04761904761904763),
#                 'rougeL': Score(precision=0.2777777777777778, recall=0.19230769230769232, fmeasure=0.2272727272727273)},
#                'longest_common_substring': 0.4666666666666667,
#                'longest_common_subsequence': 77},
#               ('### similar work one of the most similar works in the field of copyright protection and watermarking is "digital watermarking for copyright protection" by cox et al.',
#                ('we propose promptcare, a prompt watermark injection and verification framework that is used to verify the copyright of the prompt used on a suspected llm service provider.',
#                 0.8855746984481812)): {'levenshtein_distance': 0.19298245614035092,
#                'jaccard_similarity': 0.13953488372093023,
#                'bleu_score': 4.3233341924983234e-155,
#                'tfidf_cosine_similarity': 0.17457590672122467,
#                'rouge_score': {'rouge1': Score(precision=0.25925925925925924, recall=0.2692307692307692, fmeasure=0.2641509433962264),
#                 'rouge2': Score(precision=0.038461538461538464, recall=0.04, fmeasure=0.0392156862745098),
#                 'rougeL': Score(precision=0.1111111111111111, recall=0.11538461538461539, fmeasure=0.11320754716981132)},
#                'longest_common_substring': 0.4269005847953216,
#                'longest_common_subsequence': 73},
#               ('### similar work one of the most similar works in the field of copyright protection and watermarking is "digital watermarking for copyright protection" by cox et al.',
#                ('during   the verification of the watermark, the defender has the ability to embed specific triggers (i.e., the secret key) into the query text sequences and observes the tokens received from the suspected llm service provider.',
#                 0.8460875153541565)): {'levenshtein_distance': 0.23893805309734517,
#                'jaccard_similarity': 0.07692307692307693,
#                'bleu_score': 3.0953743415179487e-155,
#                'tfidf_cosine_similarity': 0.21914187885283148,
#                'rouge_score': {'rouge1': Score(precision=0.1388888888888889, recall=0.19230769230769232, fmeasure=0.16129032258064516),
#                 'rouge2': Score(precision=0.02857142857142857, recall=0.04, fmeasure=0.03333333333333333),
#                 'rougeL': Score(precision=0.1111111111111111, recall=0.15384615384615385, fmeasure=0.12903225806451615)},
#                'longest_common_substring': 0.3274336283185841,
#                'longest_common_subsequence': 74},
#               ('this work discusses various techniques for embedding watermarks into digital content to protect copyright and verify ownership.',
#                ('b.1  summary the paper introduces a framework, promptcare, aimed at protecting prompt copyright through watermark injection and verification.',
#                 0.5114053189754486)): {'levenshtein_distance': 0.24822695035460995,
#                'jaccard_similarity': 0.08571428571428572,
#                'bleu_score': 9.853445011990208e-232,
#                'tfidf_cosine_similarity': 0.06530314770397087,
#                'rouge_score': {'rouge1': Score(precision=0.21052631578947367, recall=0.23529411764705882, fmeasure=0.2222222222222222),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.15789473684210525, recall=0.17647058823529413, fmeasure=0.16666666666666669)},
#                'longest_common_substring': 0.4326241134751773,
#                'longest_common_subsequence': 61},
#               ('this work discusses various techniques for embedding watermarks into digital content to protect copyright and verify ownership.',
#                ('in this paper, we propose promptcare, the first framework for prompt copyright protection through watermark injection and verification.',
#                 0.4955151081085205)): {'levenshtein_distance': 0.24444444444444446,
#                'jaccard_similarity': 0.15151515151515152,
#                'bleu_score': 1.1195675049046784e-231,
#                'tfidf_cosine_similarity': 0.1305011295263411,
#                'rouge_score': {'rouge1': Score(precision=0.3333333333333333, recall=0.35294117647058826, fmeasure=0.34285714285714286),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.2222222222222222, recall=0.23529411764705882, fmeasure=0.22857142857142856)},
#                'longest_common_substring': 0.4444444444444444,
#                'longest_common_subsequence': 60},
#               ('this work discusses various techniques for embedding watermarks into digital content to protect copyright and verify ownership.',
#                ('among all these methods, watermarking is a promising candidate technique for prompt copyright protection due to its effectiveness.',
#                 0.4763607978820801)): {'levenshtein_distance': 0.23076923076923073,
#                'jaccard_similarity': 0.11764705882352941,
#                'bleu_score': 1.1193096620723278e-231,
#                'tfidf_cosine_similarity': 0.09786443370456027,
#                'rouge_score': {'rouge1': Score(precision=0.3333333333333333, recall=0.35294117647058826, fmeasure=0.34285714285714286),
#                 'rouge2': Score(precision=0.058823529411764705, recall=0.0625, fmeasure=0.06060606060606061),
#                 'rougeL': Score(precision=0.16666666666666666, recall=0.17647058823529413, fmeasure=0.17142857142857143)},
#                'longest_common_substring': 0.46923076923076923,
#                'longest_common_subsequence': 61},
#               ('this work discusses various techniques for embedding watermarks into digital content to protect copyright and verify ownership.',
#                ('to overcome the above hurdles, we propose promptcare: prompt copyright protection by watermark injection and verification.',
#                 0.4687466621398926)): {'levenshtein_distance': 0.2362204724409449,
#                'jaccard_similarity': 0.12121212121212122,
#                'bleu_score': 1.1832532987548623e-231,
#                'tfidf_cosine_similarity': 0.10117859857468431,
#                'rouge_score': {'rouge1': Score(precision=0.3125, recall=0.29411764705882354, fmeasure=0.30303030303030304),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.1875, recall=0.17647058823529413, fmeasure=0.1818181818181818)},
#                'longest_common_substring': 0.4330708661417323,
#                'longest_common_subsequence': 55},
#               ('this work discusses various techniques for embedding watermarks into digital content to protect copyright and verify ownership.',
#                ('prompt watermarking presents unique chal- lenges that render existing watermarking techniques devel- oped for model and dataset copyright verification ineffective.',
#                 0.45281028747558594)): {'levenshtein_distance': 0.33742331288343563,
#                'jaccard_similarity': 0.15151515151515152,
#                'bleu_score': 1.1195675049046784e-231,
#                'tfidf_cosine_similarity': 0.11674195505235428,
#                'rouge_score': {'rouge1': Score(precision=0.25, recall=0.29411764705882354, fmeasure=0.27027027027027023),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.15, recall=0.17647058823529413, fmeasure=0.16216216216216214)},
#                'longest_common_substring': 0.44171779141104295,
#                'longest_common_subsequence': 72},
#               ('this work discusses various techniques for embedding watermarks into digital content to protect copyright and verify ownership.',
#                ('to overcome the above hurdles, we propose promptcare: prompt copyright protection by watermark injection and verification.',
#                 0.9345049262046814)): {'levenshtein_distance': 0.2362204724409449,
#                'jaccard_similarity': 0.12121212121212122,
#                'bleu_score': 1.1832532987548623e-231,
#                'tfidf_cosine_similarity': 0.10117859857468431,
#                'rouge_score': {'rouge1': Score(precision=0.3125, recall=0.29411764705882354, fmeasure=0.30303030303030304),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.1875, recall=0.17647058823529413, fmeasure=0.1818181818181818)},
#                'longest_common_substring': 0.4330708661417323,
#                'longest_common_subsequence': 55},
#               ('this work discusses various techniques for embedding watermarks into digital content to protect copyright and verify ownership.',
#                ('b.1  summary the paper introduces a framework, promptcare, aimed at protecting prompt copyright through watermark injection and verification.',
#                 0.9129835963249207)): {'levenshtein_distance': 0.24822695035460995,
#                'jaccard_similarity': 0.08571428571428572,
#                'bleu_score': 9.853445011990208e-232,
#                'tfidf_cosine_similarity': 0.06530314770397087,
#                'rouge_score': {'rouge1': Score(precision=0.21052631578947367, recall=0.23529411764705882, fmeasure=0.2222222222222222),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.15789473684210525, recall=0.17647058823529413, fmeasure=0.16666666666666669)},
#                'longest_common_substring': 0.4326241134751773,
#                'longest_common_subsequence': 61},
#               ('this work discusses various techniques for embedding watermarks into digital content to protect copyright and verify ownership.',
#                ('in this paper, we propose promptcare, the first framework for prompt copyright protection through watermark injection and verification.',
#                 0.9047225117683411)): {'levenshtein_distance': 0.24444444444444446,
#                'jaccard_similarity': 0.15151515151515152,
#                'bleu_score': 1.1195675049046784e-231,
#                'tfidf_cosine_similarity': 0.1305011295263411,
#                'rouge_score': {'rouge1': Score(precision=0.3333333333333333, recall=0.35294117647058826, fmeasure=0.34285714285714286),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.2222222222222222, recall=0.23529411764705882, fmeasure=0.22857142857142856)},
#                'longest_common_substring': 0.4444444444444444,
#                'longest_common_subsequence': 60},
#               ('this work discusses various techniques for embedding watermarks into digital content to protect copyright and verify ownership.',
#                ('we propose promptcare, a prompt watermark injection and verification framework that is used to verify the copyright of the prompt used on a suspected llm service provider.',
#                 0.8855746984481812)): {'levenshtein_distance': 0.26900584795321636,
#                'jaccard_similarity': 0.13157894736842105,
#                'bleu_score': 7.178447276683369e-232,
#                'tfidf_cosine_similarity': 0.09696768538550049,
#                'rouge_score': {'rouge1': Score(precision=0.18518518518518517, recall=0.29411764705882354, fmeasure=0.22727272727272727),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.1111111111111111, recall=0.17647058823529413, fmeasure=0.13636363636363638)},
#                'longest_common_substring': 0.38596491228070173,
#                'longest_common_subsequence': 66},
#               ('this work discusses various techniques for embedding watermarks into digital content to protect copyright and verify ownership.',
#                ('during   the verification of the watermark, the defender has the ability to embed specific triggers (i.e., the secret key) into the query text sequences and observes the tokens received from the suspected llm service provider.',
#                 0.8460875153541565)): {'levenshtein_distance': 0.24336283185840712,
#                'jaccard_similarity': 0.08695652173913043,
#                'bleu_score': 3.6846889193984664e-232,
#                'tfidf_cosine_similarity': 0.04097655192892054,
#                'rouge_score': {'rouge1': Score(precision=0.1111111111111111, recall=0.23529411764705882, fmeasure=0.1509433962264151),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.08333333333333333, recall=0.17647058823529413, fmeasure=0.11320754716981131)},
#                'longest_common_substring': 0.2920353982300885,
#                'longest_common_subsequence': 66},
#               ('### main differences here are some potential differences between "promptcare" and the work by cox et al.',
#                ('b.1  summary the paper introduces a framework, promptcare, aimed at protecting prompt copyright through watermark injection and verification.',
#                 0.5114053189754486)): {'levenshtein_distance': 0.2836879432624113,
#                'jaccard_similarity': 0.11428571428571428,
#                'bleu_score': 1.1896457329133973e-231,
#                'tfidf_cosine_similarity': 0.09806824934046245,
#                'rouge_score': {'rouge1': Score(precision=0.15789473684210525, recall=0.1875, fmeasure=0.17142857142857143),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.10526315789473684, recall=0.125, fmeasure=0.11428571428571428)},
#                'longest_common_substring': 0.3617021276595745,
#                'longest_common_subsequence': 51},
#               ('### main differences here are some potential differences between "promptcare" and the work by cox et al.',
#                ('in this paper, we propose promptcare, the first framework for prompt copyright protection through watermark injection and verification.',
#                 0.4955151081085205)): {'levenshtein_distance': 0.2518518518518519,
#                'jaccard_similarity': 0.11428571428571428,
#                'bleu_score': 1.1896457329133973e-231,
#                'tfidf_cosine_similarity': 0.09193998174078086,
#                'rouge_score': {'rouge1': Score(precision=0.16666666666666666, recall=0.1875, fmeasure=0.17647058823529413),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.1111111111111111, recall=0.125, fmeasure=0.11764705882352941)},
#                'longest_common_substring': 0.37777777777777777,
#                'longest_common_subsequence': 51},
#               ('### main differences here are some potential differences between "promptcare" and the work by cox et al.',
#                ('among all these methods, watermarking is a promising candidate technique for prompt copyright protection due to its effectiveness.',
#                 0.4763607978820801)): {'levenshtein_distance': 0.2692307692307693,
#                'jaccard_similarity': 0.02631578947368421,
#                'bleu_score': 8.412065649527267e-232,
#                'tfidf_cosine_similarity': 0.0,
#                'rouge_score': {'rouge1': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.0, recall=0.0, fmeasure=0.0)},
#                'longest_common_substring': 0.35384615384615387,
#                'longest_common_subsequence': 46},
#               ('### main differences here are some potential differences between "promptcare" and the work by cox et al.',
#                ('to overcome the above hurdles, we propose promptcare: prompt copyright protection by watermark injection and verification.',
#                 0.4687466621398926)): {'levenshtein_distance': 0.21311475409836067,
#                'jaccard_similarity': 0.15151515151515152,
#                'bleu_score': 1.2578972116573994e-231,
#                'tfidf_cosine_similarity': 0.1350734836708713,
#                'rouge_score': {'rouge1': Score(precision=0.25, recall=0.25, fmeasure=0.25),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.125, recall=0.125, fmeasure=0.125)},
#                'longest_common_substring': 0.3770491803278688,
#                'longest_common_subsequence': 46},
#               ('### main differences here are some potential differences between "promptcare" and the work by cox et al.',
#                ('prompt watermarking presents unique chal- lenges that render existing watermarking techniques devel- oped for model and dataset copyright verification ineffective.',
#                 0.45281028747558594)): {'levenshtein_distance': 0.29447852760736193,
#                'jaccard_similarity': 0.05405405405405406,
#                'bleu_score': 1.0003688322288243e-231,
#                'tfidf_cosine_similarity': 0.02609042123539068,
#                'rouge_score': {'rouge1': Score(precision=0.05, recall=0.0625, fmeasure=0.05555555555555556),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.05, recall=0.0625, fmeasure=0.05555555555555556)},
#                'longest_common_substring': 0.3374233128834356,
#                'longest_common_subsequence': 55},
#               ('### main differences here are some potential differences between "promptcare" and the work by cox et al.',
#                ('to overcome the above hurdles, we propose promptcare: prompt copyright protection by watermark injection and verification.',
#                 0.9345049262046814)): {'levenshtein_distance': 0.21311475409836067,
#                'jaccard_similarity': 0.15151515151515152,
#                'bleu_score': 1.2578972116573994e-231,
#                'tfidf_cosine_similarity': 0.1350734836708713,
#                'rouge_score': {'rouge1': Score(precision=0.25, recall=0.25, fmeasure=0.25),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.125, recall=0.125, fmeasure=0.125)},
#                'longest_common_substring': 0.3770491803278688,
#                'longest_common_subsequence': 46},
#               ('### main differences here are some potential differences between "promptcare" and the work by cox et al.',
#                ('b.1  summary the paper introduces a framework, promptcare, aimed at protecting prompt copyright through watermark injection and verification.',
# ...
#                'longest_common_substring': 0.2653061224489796,
#                'longest_common_subsequence': 26},
#               ('unlike traditional ai models, llms adapt by using...',
#                ('the authors conduct experiments on six datasets and three pre-trained llms (bert, roberta, opt-1 3b), with an additional case study on llama.',
#                 0.1488356590270996)): {'levenshtein_distance': 0.19148936170212771,
#                'jaccard_similarity': 0.06060606060606061,
#                'bleu_score': 2.0138900446751835e-232,
#                'tfidf_cosine_similarity': 0.03732588803522574,
#                'rouge_score': {'rouge1': Score(precision=0.041666666666666664, recall=0.125, fmeasure=0.0625),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.041666666666666664, recall=0.125, fmeasure=0.0625)},
#                'longest_common_substring': 0.2127659574468085,
#                'longest_common_subsequence': 30},
#               ('unlike traditional ai models, llms adapt by using...',
#                ('first, usage by adversarial llm service providers.',
#                 0.14310073852539062)): {'levenshtein_distance': 0.21153846153846156,
#                'jaccard_similarity': 0.11764705882352941,
#                'bleu_score': 1.2183324802375697e-231,
#                'tfidf_cosine_similarity': 0.07244081925041987,
#                'rouge_score': {'rouge1': Score(precision=0.2857142857142857, recall=0.25, fmeasure=0.26666666666666666),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.14285714285714285, recall=0.125, fmeasure=0.13333333333333333)},
#                'longest_common_substring': 0.34615384615384615,
#                'longest_common_subsequence': 18},
#               ('unlike traditional ai models, llms adapt by using...',
#                ('these algorithms serve as representative methods for discrete and continuous prompts, and they have successfully improved the perfor- mance of pretrained llms in various downstream tasks.',
#                 0.1395406723022461)): {'levenshtein_distance': 0.160427807486631,
#                'jaccard_similarity': 0.05714285714285714,
#                'bleu_score': 2.0138900446751835e-232,
#                'tfidf_cosine_similarity': 0.03523164165337641,
#                'rouge_score': {'rouge1': Score(precision=0.038461538461538464, recall=0.125, fmeasure=0.058823529411764705),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.038461538461538464, recall=0.125, fmeasure=0.058823529411764705)},
#                'longest_common_substring': 0.1711229946524064,
#                'longest_common_subsequence': 32},
#               ('unlike traditional ai models, llms adapt by using...',
#                ('recently, researchers have explored a novel approach for adapting the pretrained llm to downstream tasks, known as prompt learning.',
#                 0.097037672996521)): {'levenshtein_distance': 0.20610687022900764,
#                'jaccard_similarity': 0.03333333333333333,
#                'bleu_score': 3.0857088441767165e-232,
#                'tfidf_cosine_similarity': 0.0,
#                'rouge_score': {'rouge1': Score(precision=0.10526315789473684, recall=0.25, fmeasure=0.14814814814814814),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.05263157894736842, recall=0.125, fmeasure=0.07407407407407407)},
#                'longest_common_substring': 0.22900763358778625,
#                'longest_common_subsequence': 30},
#               ('unlike traditional ai models, llms adapt by using...',
#                ('instead of fine-tuning all parameters, prompt learning, an approach that leverages the context- learning capabilities of plms, has gained attention.',
#                 0.7278540134429932)): {'levenshtein_distance': 0.18918918918918914,
#                'jaccard_similarity': 0.034482758620689655,
#                'bleu_score': 2.526364725772193e-232,
#                'tfidf_cosine_similarity': 0.0,
#                'rouge_score': {'rouge1': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.0, recall=0.0, fmeasure=0.0)},
#                'longest_common_substring': 0.20945945945945946,
#                'longest_common_subsequence': 31},
#               ('unlike traditional ai models, llms adapt by using...',
#                ('a smaller trigger payload can enhance stealthiness during verification.',
#                 0.6797724366188049)): {'levenshtein_distance': 0.23943661971830987,
#                'jaccard_similarity': 0.0,
#                'bleu_score': 0,
#                'tfidf_cosine_similarity': 0.0,
#                'rouge_score': {'rouge1': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.0, recall=0.0, fmeasure=0.0)},
#                'longest_common_substring': 0.30985915492957744,
#                'longest_common_subsequence': 22},
#               ('unlike traditional ai models, llms adapt by using...',
#                ('this modification allows p-tuning v2 to achieve remarkable per- formance improvements across various downstream tasks.',
#                 0.6766550540924072)): {'levenshtein_distance': 0.19491525423728817,
#                'jaccard_similarity': 0.0,
#                'bleu_score': 0,
#                'tfidf_cosine_similarity': 0.0,
#                'rouge_score': {'rouge1': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.0, recall=0.0, fmeasure=0.0)},
#                'longest_common_substring': 0.2288135593220339,
#                'longest_common_subsequence': 27},
#               ('unlike traditional ai models, llms adapt by using...',
#                ('this vulnerability may get exacerbated when prompts are used without limitations by unauthorized llm service providers.',
#                 0.6685280799865723)): {'levenshtein_distance': 0.2184873949579832,
#                'jaccard_similarity': 0.038461538461538464,
#                'bleu_score': 5.087473806581661e-232,
#                'tfidf_cosine_similarity': 0.04692402084245644,
#                'rouge_score': {'rouge1': Score(precision=0.1875, recall=0.375, fmeasure=0.25),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.0625, recall=0.125, fmeasure=0.08333333333333333)},
#                'longest_common_substring': 0.23529411764705882,
#                'longest_common_subsequence': 28},
#               ('unlike traditional ai models, llms adapt by using...',
#                ('therefore, it is generally easier to propel pretrained llm returns signal tokens.',
#                 0.6622899174690247)): {'levenshtein_distance': 0.2592592592592593,
#                'jaccard_similarity': 0.043478260869565216,
#                'bleu_score': 6.867371326126471e-232,
#                'tfidf_cosine_similarity': 0.0,
#                'rouge_score': {'rouge1': Score(precision=0.08333333333333333, recall=0.125, fmeasure=0.1),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.08333333333333333, recall=0.125, fmeasure=0.1)},
#                'longest_common_substring': 0.32098765432098764,
#                'longest_common_subsequence': 26}},
#              'Levenshtein Distance': {('unlike traditional ai models, llms adapt by using',
#                ('the prompt plays a critical role in enhancing the performance of llms on diverse downstream tasks.',
#                 0.12622034549713135)): {'levenshtein_distance': 0.22448979591836737,
#                'jaccard_similarity': 0.041666666666666664,
#                'bleu_score': 4.324223740015325e-232,
#                'tfidf_cosine_similarity': 0.04548041254429374,
#                'rouge_score': {'rouge1': Score(precision=0.0625, recall=0.125, fmeasure=0.08333333333333333),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.0625, recall=0.125, fmeasure=0.08333333333333333)},
#                'longest_common_substring': 0.25510204081632654,
#                'longest_common_subsequence': 25},
#               ('unlike traditional ai models, llms adapt by using',
#                ('first, usage by adversarial llm service providers.',
#                 0.1222829818725586)): {'levenshtein_distance': 0.16000000000000003,
#                'jaccard_similarity': 0.125,
#                'bleu_score': 1.2508498911928379e-231,
#                'tfidf_cosine_similarity': 0.07244081925041987,
#                'rouge_score': {'rouge1': Score(precision=0.2857142857142857, recall=0.25, fmeasure=0.26666666666666666),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.14285714285714285, recall=0.125, fmeasure=0.13333333333333333)},
#                'longest_common_substring': 0.34,
#                'longest_common_subsequence': 17},
#               ('unlike traditional ai models, llms adapt by using',
#                ('the authors conduct experiments on six datasets and three pre-trained llms (bert, roberta, opt-1 3b), with an additional case study on llama.',
#                 0.09603714942932129)): {'levenshtein_distance': 0.18439716312056742,
#                'jaccard_similarity': 0.0625,
#                'bleu_score': 1.5148209014603573e-232,
#                'tfidf_cosine_similarity': 0.03732588803522574,
#                'rouge_score': {'rouge1': Score(precision=0.041666666666666664, recall=0.125, fmeasure=0.0625),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.041666666666666664, recall=0.125, fmeasure=0.0625)},
#                'longest_common_substring': 0.20567375886524822,
#                'longest_common_subsequence': 29},
#               ('unlike traditional ai models, llms adapt by using',
#                ('these algorithms serve as representative methods for discrete and continuous prompts, and they have successfully improved the perfor- mance of pretrained llms in various downstream tasks.',
#                 0.09381449222564697)): {'levenshtein_distance': 0.160427807486631,
#                'jaccard_similarity': 0.058823529411764705,
#                'bleu_score': 1.5148209014603573e-232,
#                'tfidf_cosine_similarity': 0.03523164165337641,
#                'rouge_score': {'rouge1': Score(precision=0.038461538461538464, recall=0.125, fmeasure=0.058823529411764705),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.038461538461538464, recall=0.125, fmeasure=0.058823529411764705)},
#                'longest_common_substring': 0.1657754010695187,
#                'longest_common_subsequence': 31},
#               ('unlike traditional ai models, llms adapt by using',
#                ('recently, researchers have explored a novel approach for adapting the pretrained llm to downstream tasks, known as prompt learning.',
#                 0.08852273225784302)): {'levenshtein_distance': 0.2137404580152672,
#                'jaccard_similarity': 0.034482758620689655,
#                'bleu_score': 2.481038162867807e-232,
#                'tfidf_cosine_similarity': 0.0,
#                'rouge_score': {'rouge1': Score(precision=0.10526315789473684, recall=0.25, fmeasure=0.14814814814814814),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.05263157894736842, recall=0.125, fmeasure=0.07407407407407407)},
#                'longest_common_substring': 0.22137404580152673,
#                'longest_common_subsequence': 29},
#               ('unlike traditional ai models, llms adapt by using',
#                ('instead of fine-tuning all parameters, prompt learning, an approach that leverages the context- learning capabilities of plms, has gained attention.',
#                 0.7330427765846252)): {'levenshtein_distance': 0.18243243243243246,
#                'jaccard_similarity': 0.03571428571428571,
#                'bleu_score': 1.9866600550722573e-232,
#                'tfidf_cosine_similarity': 0.0,
#                'rouge_score': {'rouge1': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.0, recall=0.0, fmeasure=0.0)},
#                'longest_common_substring': 0.20270270270270271,
#                'longest_common_subsequence': 30},
#               ('unlike traditional ai models, llms adapt by using',
#                ('a smaller trigger payload can enhance stealthiness during verification.',
#                 0.6901046633720398)): {'levenshtein_distance': 0.23943661971830987,
#                'jaccard_similarity': 0.0,
#                'bleu_score': 0,
#                'tfidf_cosine_similarity': 0.0,
#                'rouge_score': {'rouge1': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.0, recall=0.0, fmeasure=0.0)},
#                'longest_common_substring': 0.29577464788732394,
#                'longest_common_subsequence': 21},
#               ('unlike traditional ai models, llms adapt by using',
#                ('this vulnerability may get exacerbated when prompts are used without limitations by unauthorized llm service providers.',
#                 0.6764916777610779)): {'levenshtein_distance': 0.2100840336134454,
#                'jaccard_similarity': 0.04,
#                'bleu_score': 4.324223740015325e-232,
#                'tfidf_cosine_similarity': 0.04692402084245644,
#                'rouge_score': {'rouge1': Score(precision=0.1875, recall=0.375, fmeasure=0.25),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.0625, recall=0.125, fmeasure=0.08333333333333333)},
#                'longest_common_substring': 0.226890756302521,
#                'longest_common_subsequence': 27},
#               ('unlike traditional ai models, llms adapt by using',
#                ('therefore, it is generally easier to propel pretrained llm returns signal tokens.',
#                 0.6755882501602173)): {'levenshtein_distance': 0.2592592592592593,
#                'jaccard_similarity': 0.045454545454545456,
#                'bleu_score': 6.034940380417626e-232,
#                'tfidf_cosine_similarity': 0.0,
#                'rouge_score': {'rouge1': Score(precision=0.08333333333333333, recall=0.125, fmeasure=0.1),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.08333333333333333, recall=0.125, fmeasure=0.1)},
#                'longest_common_substring': 0.30864197530864196,
#                'longest_common_subsequence': 25},
#               ('unlike traditional ai models, llms adapt by using',
#                ('this modification allows p-tuning v2 to achieve remarkable per- formance improvements across various downstream tasks.',
#                 0.6753638386726379)): {'levenshtein_distance': 0.19491525423728817,
#                'jaccard_similarity': 0.0,
#                'bleu_score': 0,
#                'tfidf_cosine_similarity': 0.0,
#                'rouge_score': {'rouge1': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rouge2': Score(precision=0.0, recall=0.0, fmeasure=0.0),
#                 'rougeL': Score(precision=0.0, recall=0.0, fmeasure=0.0)},
#                'longest_common_substring': 0.22033898305084745,
#                'longest_common_subsequence': 26}}})

# %%
sentence1= "This is Michael and i love it"
sentence2= "Michael is my brother and i love him"

match = textdistance.lcsseq(sentence1, sentence2)
scores= len(match) / max(len(sentence1), len(sentence2))
print(match)
# Out:
# Michael and i love i
